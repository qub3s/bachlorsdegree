# %% [markdown]
# # Exercise Sheet 3 - Covid-19 Classification using Transfer Learning
#
# - Deep Learning for Computer Vision - Winter Term 2023/24
# - Organizers: Anwai Archit, Sushmita Nair, Constantin Pape
# - Tutors: Ahsan Ali, Anwai Archit, Lukas Friedrich, Piklu Mallick, Sushmita Nair, Ayush Paliwal
# - Due date: **Tuesday**, Dec 5, before 10:00
#
# ## Time Required to Solve this Exercise Sheet
#
# As you will train deep CNNs on this exercise sheet, model training will require an increased amount of time. So we recommend to start working on this sheet early.
#
# ## Topic
#
# In this exercise, you will solve an image classification task from medical imaging: classification in Chest X-Ray images into patients with Covid-19, Pneunomia or Healthy. We will use a subset of the dataset from a kaggle challenge for this. (https://www.kaggle.com/datasets/prashant268/chest-xray-covid19-pneumonia)
#
# The main focus of this exercise is transfer learning and you will approach the classification task with three different approaches:
#
#     Training ResNets from scratch. (Note that we will use the ResNet implementation from torchvision throughout the exercise).
#     Training ResNets pretrained on ImageNet.
#     Training ResNets pretrained on RadImageNet, a large radiology dataset.
#
# In addition you can combine these approaches with other methods to improve the model at the end and upload your best solution on a hold-out test set. This is explained in more details at the end of the exercise.

# %% [markdown]
# ### Hints
#
# In the first part of the exercise you will train ResNets from scratch, analyze the effects of deeper models with small training data and use data augmentations. In the second part, you will solve the same task using pretrained ResNets (from ImageNet - pretrained on natural images; and RadImageNet - pretrained on the medical imaging domain).
#
# To understand the background of this exercise, you can:
# - Review the lectures
#     - Lecture 3 on CNNs
#     - Lecture 4 on Transfer Learning and Augmentaion
# - Check out the [RadImageNet publication](https://doi.org/10.1148/ryai.210315).
#
# At the end of the exercise you should further improve your model. You can draw upon a number of techniques we discussed for improving model performance. The predictions from your best model on a hold-out test set should be uploaded together with the exercise. More explanation is given at the end of the exercise sheet.
#
# _Do not hesitate to ask questions and ideally discuss them with the fellow students on Rocket Chat! We will monitor the channel to provide you help if your discussions get stuck._

# %% [markdown]
# ## IMPORTANT SUBMISSION INSTRUCTIONS
# - **You need to answer all the questions in written form**
# - When you are done, download the notebook from Kaggle and **rename** it to `Tutorial_<X>_<surname1>_<surname2>_<surname3>.ipynb`
# - For the final submission:
#     - Submit the **Jupyter Notebook** (.ipynb file). Upload them on `Stud.IP` -> `Deep Learning for Computer Vision` -> `Files` -> `Submission for Homework 3` -> `Notebook`
#     - Submit the **Challenge Results** (.csv file) (for the unlabeled images, namely `unknown`). Upload them on `Stud.IP` -> `Deep Learning for Computer Vision` -> `Files` -> `Submission for Homework 3` -> `Challenge Results`
# - Make only one submission of the exercise and results per group.
# - The deadline is strict.
# - You have to present the exercise in the tutorials. We have a high ratio of students to tutors, so please decide which team member presents which part beforehand.
#
# Implementation
# - Do not change the cells which are marked as `DO NOT CHANGE`, similarly write your solution into the cells marked with TODOs and answer the **questions** asked. In addition to the python packages loaded below, you are allowed to use any packages you want.

# %% [markdown]
# **Importing required libraries:**
#
# We have provided the most essential libraries to be used for the exercise. Feel free to add modules as per your requirement.

# %%
import os
from glob import glob
from IPython.display import FileLink

import numpy as np
import imageio.v3 as imageio
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import torch
import torchvision
from torch import nn
import torch.optim as optim
import torchvision.transforms.v2 as transforms

# %pip install barbar
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/datapoints/__init__.py:12: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/v2/__init__.py:54: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# Collecting barbar
#   Downloading barbar-0.2.1-py3-none-any.whl (3.9 kB)
# Installing collected packages: barbar
# Successfully installed barbar-0.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
#size = 512
#os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:<"+ str(size) + ">"

# %%
plt.rcParams["savefig.bbox"] = 'tight'


def show(imgs):
    if not isinstance(imgs, list):
        imgs = [imgs]
    fig, axs = plt.subplots(ncols=len(imgs), squeeze=False)
    for i, img in enumerate(imgs):
        img = img.detach()
        img = torchvision.transforms.functional.to_pil_image(img)
        axs[0, i].imshow(np.asarray(img))
        axs[0, i].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

# %%
# Setting up the device (make sure device returns "cuda" to use of the GPUs on kaggle)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ### Getting the Required Functionalities
#
# We first download and import `ex3_utils.py`, which in which functions for training evaluation etc. are already implemented (similar to the previous exercise). You can download this file and inspect it on your computer to understand the functions it contains.
#
# You can either download it from google drive as here or from Stud.IP (it's provided there in the same folder as this notebook.)

# %%
# DO NOT CHANGE
# Download `ex3_utils.py` from Google Drive in Kaggle
# !conda install -y gdown

# File Location - https://drive.google.com/file/d/1VfnvYTwNbDdwFArYZqZuqhkmw9d39IgQ/view?usp=sharing (we only need the id)
# !gdown 1VfnvYTwNbDdwFArYZqZuqhkmw9d39IgQ
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.10.0
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - gdown
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.11.17 |       hbcca054_0         151 KB  conda-forge
#     certifi-2023.11.17         |     pyhd8ed1ab_0         155 KB  conda-forge
#     filelock-3.13.1            |     pyhd8ed1ab_0          15 KB  conda-forge
#     gdown-4.7.1                |     pyhd8ed1ab_0          19 KB  conda-forge
#     openssl-3.2.0              |       hd590300_1         2.7 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   filelock           conda-forge/noarch::filelock-3.13.1-pyhd8ed1ab_0
#   gdown              conda-forge/noarch::gdown-4.7.1-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2023.7.22-hbcca054_0 --> 2023.11.17-hbcca054_0
#   certifi                            2023.7.22-pyhd8ed1ab_0 --> 2023.11.17-pyhd8ed1ab_0
#   openssl                                  3.1.4-hd590300_0 --> 3.2.0-hd590300_1
#
#
#
# Downloading and Extracting Packages
# certifi-2023.11.17   | 155 KB    |                                       |   0%
# gdown-4.7.1          | 19 KB     |                                       |   0%
#
# openssl-3.2.0        | 2.7 MB    |                                       |   0%
#
#
# ca-certificates-2023 | 151 KB    |                                       |   0%
#
#
#
# certifi-2023.11.17   | 155 KB    | ###8                                  |  10%
#
# openssl-3.2.0        | 2.7 MB    | #9                                    |   5%
#
#
# ca-certificates-2023 | 151 KB    | ###############7                      |  43%
# gdown-4.7.1          | 19 KB     | ###############################6      |  85%
#
#
#
# filelock-3.13.1      | 15 KB     | ##################################### | 100%
#
#
# ca-certificates-2023 | 151 KB    | ##################################### | 100%
# gdown-4.7.1          | 19 KB     | ##################################### | 100%
#
#
#
# filelock-3.13.1      | 15 KB     | ##################################### | 100%
#
# certifi-2023.11.17   | 155 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1VfnvYTwNbDdwFArYZqZuqhkmw9d39IgQ
# From (redirected): https://drive.google.com/uc?id=1VfnvYTwNbDdwFArYZqZuqhkmw9d39IgQ&confirm=t&uuid=aecfecd4-68c4-4f22-ac39-e177dc9cf780
# To: /kaggle/working/ex3_utils.py
# 100%|██████████████████████████████████████| 10.4k/10.4k [00:00<00:00, 43.1MB/s]

# %%
# DO NOT CHANGE
# Import `ex3_utils.py`
import ex3_utils as utils
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Data Preparation
#
# We download the data from google drive and unzip the data in `"/kaggle/working/covid19"`.

# %%
# DO NOT CHANGE
# Downloading the "Chest X-ray (Covid-19 & Pneumonia)" data from owncloud
# !wget https://owncloud.gwdg.de/index.php/s/dcvhmxtksDDDtK8/download -O covid19-xray.zip

# Unzipping the dataset
# !unzip -q "/kaggle/working/covid19-xray.zip"
# Out:
# --2023-11-29 15:38:43--  https://owncloud.gwdg.de/index.php/s/dcvhmxtksDDDtK8/download
# Resolving owncloud.gwdg.de (owncloud.gwdg.de)... 134.76.23.45
# Connecting to owncloud.gwdg.de (owncloud.gwdg.de)|134.76.23.45|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 154704441 (148M) [application/zip]
# Saving to: ‘covid19-xray.zip’
#
# covid19-xray.zip    100%[===================>] 147.54M  44.6MB/s    in 3.3s
#
# 2023-11-29 15:38:46 (44.6 MB/s) - ‘covid19-xray.zip’ saved [154704441/154704441]

# %%
# DO NOT CHANGE
# Setting the path to covid-19 dataset
root_dir = "/kaggle/working/"
data_folder = os.path.join(root_dir, "covid19")

# %% [markdown]
# **Data exploration**
#
# The data is stored in the root folder `covid19` (in `"/kaggle/working"`) and contains four subfolders, namely `train`, `val`, `test` and `unknown` with training / validation / testing split and the hold-out test set, respectively. Each of these (except `unknown`) contains subfolders with the images for the respective classes. As a first step, we will visualize some of the images and labels from the training data.
#
# We will not use the `unknown` directory for training or evaluation, but will only use it for prediction with the best model at the end.

# %%
# DO NOT CHANGE
# Checking the number of classes
train_class_dirs = glob(os.path.join(data_folder, "train", "*"))
val_class_dirs = glob(os.path.join(data_folder, "val", "*"))
test_class_dirs = glob(os.path.join(data_folder, "test", "*"))
assert len(train_class_dirs) == len(val_class_dirs) == len(test_class_dirs) == 3

# %%
# DO NOT CHANGE
# Checking the expected structure of all images
image_paths = glob(os.path.join(data_folder, "**", "*.jpg"), recursive=True)
assert len(image_paths) == (450 + 150 + 225 + 5607), len(image_paths)  # 450 train samples, 150 val samples, 225 test samples, 5607 unlabeled samples (hold-out test)

# %% [markdown]
# Let's plot samples from each class in the training set:

# %%
# Classes available for the task
classes = ["COVID19", "NORMAL", "PNEUMONIA"]
num_classes = 3

# %%
out =[]
for path in train_class_dirs:
    dirList = os.listdir(path)
    for i in range(num_classes):
        out.append(torchvision.io.read_image(str(path) + "/" + str(dirList[i])))

grid = torchvision.utils.make_grid(out, nrow=3)
print("First row: COVID19, second: normal, third: pneunomia")
show(grid)
# Out:
# First row: COVID19, second: normal, third: pneunomia

# %% [markdown]
# You should see x-ray images from each class and their corresponding labels in their titles. To reflect on our understanding of the dataset, please answer the following **questions**:
# - How many classes are provided in the datasets?
# - Are the images balanced along all the classes in the respective data splits?

# %%
print('Number of clases are ' + str(num_classes))

for path in train_class_dirs:
    dirList = os.listdir(path)
    print('There are ' + str(len(dirList)) + ' entries for ' + str(path.rsplit('/', 1)[-1]) + '.' )
# Out:
# Number of clases are 3
# There are 150 entries for NORMAL.
# There are 150 entries for COVID19.
# There are 150 entries for PNEUMONIA.

# %% [markdown]
# Let's set the directories for the respective datasets

# %%
# Splits for the dataset 
train_dir = os.path.join(data_folder, "train")
val_dir = os.path.join(data_folder, "val")
test_dir = os.path.join(data_folder, "test")
unknown_dir = os.path.join(data_folder, "unknown")

# %% [markdown]
# Now, we obtain the statistics (mean and standard deviation) from the training dataset to be used for normalizing the datasets

# %%
# DO NOT CHANGE
train_images = []
for class_name in classes:
    train_images.extend(glob(os.path.join(train_dir, class_name, "*.jpg")))

to_tensor = torchvision.transforms.ToTensor()
imgs = torch.stack([to_tensor(imageio.imread(im)) for im in train_images])
print(imgs.shape)

# And then compute the mean and standard deviation independently for the image channels.
# (The channels are stored in dim=1, by excluding this below we achieve this.)
mean = torch.mean(imgs, dim=(0, 2, 3))
std = torch.std(imgs, dim=(0, 2, 3))

# Delete the images again in order to save memory.
del imgs

print(mean)
print(std)
# Out:
# torch.Size([450, 3, 512, 512])
# tensor([0.4949, 0.4952, 0.4957])
# tensor([0.2298, 0.2298, 0.2298])

# %%
train_dataset_mean = mean
train_dataset_std = std

# %% [markdown]
# **Implement PyTorch dataloader**
#
# As a next step, we implement a `torch.utils.data.Dataset` followed by the `torch.utils.data.DataLoader` to have access to our data during training, validation and testing. In our case, the data is stored in a format that is already compatible with `torchvision.datasets.ImageFolder`.

# %% [markdown]
# To use the image data in PyTorch it first needs to be transformed. You can use the transformations from [torchvision.transforms](https://pytorch.org/vision/0.9/transforms.html) for this. Here, we need to:
# - Convert the image data to a `torch.tensor` (`transforms.ToTensor`)
# - Standardize the inputs based on their data statistics (`transforms.Normalize`)
# - Resize the images (`transforms.Resize`). Note that resizing is not strictly necessary, but will speed up training and resize the images to a size that better matches the ImageNet pretraining data.
#
# To combine several transforms together, you can use `torchvision.transforms.Compose` by passing the list of 'transform' objects to compose.

# %%
# We resize the images to the size 256 x 256 to speed up training
height = width = 256

# Get the usual transforms to have the inputs from dataloaders as expected
def get_transforms(height, width, mean, std):
    # TODO: YOUR CODE HERE
    transform = transforms.Compose([transforms.ToImageTensor(), transforms.ConvertImageDtype(), transforms.Normalize(mean, std), transforms.Resize((height, width))])
    return transform

# %%
# Batch size
batch_size = 64  # TODO: YOUR CHOICE HERE

# Datasets
# TODO: YOUR SOLUTION HERE
train_dataset = torchvision.datasets.ImageFolder(train_dir, transform=get_transforms(height, width, train_dataset_mean, train_dataset_std))
val_dataset = torchvision.datasets.ImageFolder(val_dir, transform=get_transforms(height, width, train_dataset_mean, train_dataset_std))
test_dataset = torchvision.datasets.ImageFolder(test_dir, transform=get_transforms(height, width, train_dataset_mean, train_dataset_std))

# Dataloaders
# TODO: YOUR SOLUTION HERE
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size)

# %% [markdown]
# Now let's visualize the images after transformation as they are returned from the training loader.

# %%
# Function to show images
fig = plt.figure(figsize=(10, 15))
def imshow(img):
    img = img / 2 + 0.5  # unnormalise
    npimg = img.numpy()
    plt.axis('off')
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

# Obtain random training images
dataiter = iter(train_loader)
images, labels = next(dataiter)

# Show the images
imshow(torchvision.utils.make_grid(images))

print(' '.join('%5s, ' % classes[labels[j]] for j in range(len(labels))))
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,  COVID19,

# %% [markdown]
# ## Architecture
#
# We will use the ResNet implementation from torchvision, see https://pytorch.org/vision/stable/models.html, for this exercise.
#
# - We start with the smallest ResNet model, the ResNet18 (https://pytorch.org/vision/main/models/generated/torchvision.models.resnet18.html)
# - And will then use deeper ResNets to explore how well larger models can be trained on a small dataset.
# - To use random weight initialization (in order to train from scratch), you can just create models without passing additional arguments like so: `torchvision.models.<MODEL_NAME>()`.

# %% [markdown]
# We need to adapt the model to fit with our purpose. For this, we must change the output dimension of the last fully-connected layer to consider the number of classes in our problem. Let's check the last layer out.

# %%
# Let's get the resnet18 architecture and understanding the backbone (in order to adapt it to our problem)
# TODO: YOUR SOLUTION HERE
model = torchvision.models.resnet18()
#print(model)

# %% [markdown]
# We see above that there is a component called `fc` that consists of a `Linear` layer. To make use of ResNet18 for our classification task, we need to change the `out_features` of the linear layer to the number of classes of our problem. In our case, it's `num_classes` (=3).

# %%
print(model.fc)
# Out:
# Linear(in_features=512, out_features=1000, bias=True)

# %% [markdown]
# To replace the last layer (classification layer) you can use the following code. (Here we provide a stand-alone code snippet)
#
# ```python
# import torchvision
# import torch.nn as nn
#
# model = torchvision.models.resnet18()
#
# # Let's replace the "fully connected" layer to match our expected output classes
# model.fc = nn.Linear(<INPUT_FEATURES>, <OUTPUT_CLASSES>)
# model.to(device)
# ```

# %%
# Replacing the last layer(s) of ResNet18 to match our number of classes
# TODO: YOUR SOLUTION HERE
model.fc = nn.Linear(512, num_classes)
model.to(device)


# Let's define the checkpoint name where the specific model checkpoint will be saved
model_name = "RestNet18Adjusted"
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path)
# Out:
# The model checkpoint will be saved here:  /kaggle/working/covid-19-RestNet18Adjusted-from-scratch.pt

# %% [markdown]
# If you now display the model (using `print(model)`) you should see that its last layer has been updated.

# %%
#print(model)

# %% [markdown]
# ### Training
#
# Let's train the model for 10 epochs, using the `Adam` optimizer, `CrossEntropyLoss` as the criterion (loss function) and a learning rate scheduler (e.g. `ReduceLROnPlateau`).

# %%
# Clearing the GPU cache
torch.cuda.empty_cache()


print("Starting training from scratch with network: ", model_name)

epochs = 10
lr = 1e-5

# TODO: YOUR SOLUTION HERE
# Optimizer and loss configurations
criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.Adam(model.parameters(), lr=lr)  # optimizer
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)  # learning rate scheduler



# Initializing the early stopping of the training
early_stopping = utils.EarlyStopping(checkpoint_path)


# HINT: open the 'ex3_utils.py' file to understand the arguments of 'run_training'
acc, val_acc, loss, val_loss = utils.run_training(train_loader, val_loader, model, epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)
# Out:
# Starting training from scratch with network:  RestNet18Adjusted
# 450/450: [============================>...] - ETA 6.6ss
# Epoch: 1
# Training Loss: 1.265 , Training Accuracy:0.333 => Validation Loss: 1.190, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 2
# Training Loss: 1.290 , Training Accuracy:0.278 => Validation Loss: 1.217, Validation Accuracy: 0.500
# EarlyStopping Counter: 1 out of 5
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 3
# Training Loss: 1.101 , Training Accuracy:0.256 => Validation Loss: 1.092, Validation Accuracy: 0.487
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 4
# Training Loss: 1.038 , Training Accuracy:0.629 => Validation Loss: 1.035, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 5
# Training Loss: 1.038 , Training Accuracy:0.333 => Validation Loss: 1.015, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 6
# Training Loss: 1.040 , Training Accuracy:0.331 => Validation Loss: 1.005, Validation Accuracy: 0.340
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 7
# Training Loss: 1.028 , Training Accuracy:0.316 => Validation Loss: 0.998, Validation Accuracy: 0.387
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 8
# Training Loss: 1.008 , Training Accuracy:0.338 => Validation Loss: 0.989, Validation Accuracy: 0.480
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 9
# Training Loss: 0.984 , Training Accuracy:0.416 => Validation Loss: 0.976, Validation Accuracy: 0.560
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 10
# Training Loss: 0.962 , Training Accuracy:0.467 => Validation Loss: 0.959, Validation Accuracy: 0.600
# Finished Training

# %% [markdown]
# Now, let's see how the accuracy and loss plots look for our training.

# %%
# Training and validation accuracy plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(acc, val_acc, 'Accuracy')


# Training and validation loss plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(loss, val_loss, 'Loss')

# %% [markdown]
# ### Evaluation on the test set
#
# Let's check the test accuracy and confusion matrix. All the required functionality is already provided in `ex3_utils.py` and you just need to read the corresponding functions to understand how to call them here.

# %%
# Loading the best model for inference (NOTE: you should load the checkpoints to the expected model architecture, else you might get some mismatch errors)
# TODO: YOUR SOLUTION HERE
#load the trained weights
model.load_state_dict(torch.load(checkpoint_path))


# Provide the testing dataset wrapped in a dataloader to check for inference
# TODO: YOUR SOLUTION HERE
correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))
# Out:
# Accuracy of /kaggle/working/covid-19-RestNet18Adjusted-from-scratch.pt on the Test Images: 56 %

# %%
# Get the confusion matrix for the test dataset
# TODO: YOUR SOLUTION HERE
#classes, test_loader, net, device, view_cm=False
cm = utils.get_confusion_matrix(classes, test_loader, model, device)


# See the precision, recall and accuracy per class for the test dataset
# TODO: YOUR SOLUTION HERE
utils.check_precision_recall_accuracy(cm, classes)
# Out:
# COVID19 - recall :  0.94  precision :  0.31333333  accuracy :  0.7644445
# NORMAL - recall :  0.67391306  precision :  0.62  accuracy :  0.7733333
# PNEUMONIA - recall :  0.4389313  precision :  0.76666665  accuracy :  0.59555554

# %%
# Check the confusion matrix heatmap to visually see the evaluation on the test set
# TODO: YOUR SOLUTION HERE
utils.visualize_confusion_matrix(cm, classes, correct, total)
# Out:
# 0.5666666666666667

# %% [markdown]
# Now let's try training deeper ResNet architectures using the same hyperparameters from above:
# - Train and evaluate a ResNet34 from scratch.
# - Train and evaluate a ResNet50 from scratch.

# %%
# TODO: YOUR SOLUTIONS HERE


# HINT: (for the workflow)
#    - Start with training a ResNet34:
#          - Updating the last layers (training the network from scratch)
#          - REMEMBER: Save the respective checkpoints uniquely, and initialize the early stopping with them.
#          - Use the expected hyperparameters for training
#          - Observe the loss and accuracy curves for training and validation
#    - Next, train a ResNet50 (following the same suggestion as above)
#    - Finally, evaluate both the trained models from above on the test set and answer the questions.

# %%
model = torchvision.models.resnet34()

# %%
# Replacing the last layer(s) of ResNet34 to match our number of classes
# TODO: YOUR SOLUTION HERE
model.fc = nn.Linear(512, num_classes)
model.to(device)

# Let's define the checkpoint name where the specific model checkpoint will be saved
model_name = "RestNet34Adjusted"
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path34 = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path34)

# Clearing the GPU cache
torch.cuda.empty_cache()

print("Starting training from scratch with network: ", model_name)

epochs = 50
lr = 1e-3

# TODO: YOUR SOLUTION HERE
# Optimizer and loss configurations
criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.Adam(model.parameters(), lr=lr)  # optimizer
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)  # learning rate scheduler

# Initializing the early stopping of the training
early_stopping = utils.EarlyStopping(checkpoint_path34)

# HINT: open the 'ex3_utils.py' file to understand the arguments of 'run_training'
acc, val_acc, loss, val_loss = utils.run_training(train_loader, val_loader, model, epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)
# Out:
# The model checkpoint will be saved here:  /kaggle/working/covid-19-RestNet34Adjusted-from-scratch.pt
# Starting training from scratch with network:  RestNet34Adjusted
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 1
# Training Loss: 2.381 , Training Accuracy:0.384 => Validation Loss: 16.443, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 2
# Training Loss: 17.292 , Training Accuracy:0.578 => Validation Loss: 215.209, Validation Accuracy: 0.333
# EarlyStopping Counter: 1 out of 5
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 3
# Training Loss: 81.584 , Training Accuracy:0.098 => Validation Loss: 1.115, Validation Accuracy: 0.320
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 4
# Training Loss: 1.752 , Training Accuracy:0.196 => Validation Loss: 1.729, Validation Accuracy: 0.333
# EarlyStopping Counter: 1 out of 5
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 5
# Training Loss: 1.577 , Training Accuracy:0.289 => Validation Loss: 1.609, Validation Accuracy: 0.333
# EarlyStopping Counter: 2 out of 5
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 6
# Training Loss: 1.636 , Training Accuracy:0.044 => Validation Loss: 1.114, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 7
# Training Loss: 1.286 , Training Accuracy:0.044 => Validation Loss: 1.085, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 8
# Training Loss: 1.125 , Training Accuracy:0.224 => Validation Loss: 1.079, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 9
# Training Loss: 1.099 , Training Accuracy:0.333 => Validation Loss: 1.069, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 10
# Training Loss: 1.098 , Training Accuracy:0.333 => Validation Loss: 1.063, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 11
# Training Loss: 1.098 , Training Accuracy:0.333 => Validation Loss: 1.061, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 12
# Training Loss: 1.097 , Training Accuracy:0.333 => Validation Loss: 1.060, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 13
# Training Loss: 1.096 , Training Accuracy:0.333 => Validation Loss: 1.059, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 14
# Training Loss: 1.094 , Training Accuracy:0.333 => Validation Loss: 1.058, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 15
# Training Loss: 1.092 , Training Accuracy:0.333 => Validation Loss: 1.056, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 16
# Training Loss: 1.091 , Training Accuracy:0.333 => Validation Loss: 1.054, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 17
# Training Loss: 1.089 , Training Accuracy:0.333 => Validation Loss: 1.052, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 18
# Training Loss: 1.088 , Training Accuracy:0.333 => Validation Loss: 1.050, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 19
# Training Loss: 1.084 , Training Accuracy:0.333 => Validation Loss: 1.046, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 20
# Training Loss: 1.082 , Training Accuracy:0.333 => Validation Loss: 1.042, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 21
# Training Loss: 1.077 , Training Accuracy:0.333 => Validation Loss: 1.036, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 22
# Training Loss: 1.075 , Training Accuracy:0.333 => Validation Loss: 1.029, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 23
# Training Loss: 1.066 , Training Accuracy:0.322 => Validation Loss: 1.017, Validation Accuracy: 0.367
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 24
# Training Loss: 1.062 , Training Accuracy:0.333 => Validation Loss: 1.004, Validation Accuracy: 0.387
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 25
# Training Loss: 1.043 , Training Accuracy:0.364 => Validation Loss: 0.978, Validation Accuracy: 0.407
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 26
# Training Loss: 1.052 , Training Accuracy:0.396 => Validation Loss: 0.954, Validation Accuracy: 0.473
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 27
# Training Loss: 0.993 , Training Accuracy:0.507 => Validation Loss: 0.881, Validation Accuracy: 0.473
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 28
# Training Loss: 0.883 , Training Accuracy:0.551 => Validation Loss: 1.233, Validation Accuracy: 0.393
# EarlyStopping Counter: 1 out of 5
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 29
# Training Loss: 1.384 , Training Accuracy:0.136 => Validation Loss: 0.965, Validation Accuracy: 0.540
# EarlyStopping Counter: 2 out of 5
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 30
# Training Loss: 0.938 , Training Accuracy:0.578 => Validation Loss: 0.897, Validation Accuracy: 0.540
# EarlyStopping Counter: 3 out of 5
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 31
# Training Loss: 0.869 , Training Accuracy:0.569 => Validation Loss: 0.822, Validation Accuracy: 0.547
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 32
# Training Loss: 0.756 , Training Accuracy:0.593 => Validation Loss: 0.787, Validation Accuracy: 0.547
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 33
# Training Loss: 0.789 , Training Accuracy:0.576 => Validation Loss: 0.781, Validation Accuracy: 0.547
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 34
# Training Loss: 0.729 , Training Accuracy:0.598 => Validation Loss: 0.769, Validation Accuracy: 0.573
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 35
# Training Loss: 0.723 , Training Accuracy:0.596 => Validation Loss: 0.762, Validation Accuracy: 0.573
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 36
# Training Loss: 0.706 , Training Accuracy:0.602 => Validation Loss: 0.753, Validation Accuracy: 0.580
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 37
# Training Loss: 0.698 , Training Accuracy:0.598 => Validation Loss: 0.751, Validation Accuracy: 0.580
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 38
# Training Loss: 0.682 , Training Accuracy:0.604 => Validation Loss: 0.738, Validation Accuracy: 0.580
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 39
# Training Loss: 0.678 , Training Accuracy:0.602 => Validation Loss: 0.729, Validation Accuracy: 0.593
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 40
# Training Loss: 0.688 , Training Accuracy:0.604 => Validation Loss: 0.722, Validation Accuracy: 0.600
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 41
# Training Loss: 0.687 , Training Accuracy:0.598 => Validation Loss: 0.718, Validation Accuracy: 0.607
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 42
# Training Loss: 0.659 , Training Accuracy:0.616 => Validation Loss: 0.706, Validation Accuracy: 0.607
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 43
# Training Loss: 0.650 , Training Accuracy:0.607 => Validation Loss: 0.699, Validation Accuracy: 0.607
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 44
# Training Loss: 0.642 , Training Accuracy:0.596 => Validation Loss: 0.694, Validation Accuracy: 0.627
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 45
# Training Loss: 0.627 , Training Accuracy:0.569 => Validation Loss: 0.680, Validation Accuracy: 0.633
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 46
# Training Loss: 0.632 , Training Accuracy:0.593 => Validation Loss: 0.677, Validation Accuracy: 0.640
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 47
# Training Loss: 0.608 , Training Accuracy:0.576 => Validation Loss: 0.664, Validation Accuracy: 0.660
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 48
# Training Loss: 0.588 , Training Accuracy:0.589 => Validation Loss: 0.642, Validation Accuracy: 0.667
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 49
# Training Loss: 0.632 , Training Accuracy:0.596 => Validation Loss: 0.669, Validation Accuracy: 0.720
# EarlyStopping Counter: 1 out of 5
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 50
# Training Loss: 0.584 , Training Accuracy:0.598 => Validation Loss: 0.660, Validation Accuracy: 0.660
# EarlyStopping Counter: 2 out of 5
# Finished Training

# %%
# Training and validation accuracy plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(acc, val_acc, 'Accuracy')

# Training and validation loss plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(loss, val_loss, 'Loss')

# %%
# Loading the best model for inference (NOTE: you should load the checkpoints to the expected model architecture, else you might get some mismatch errors)
# TODO: YOUR SOLUTION HERE
#load the trained weights
model.load_state_dict(torch.load(checkpoint_path34))


# Provide the testing dataset wrapped in a dataloader to check for inference
# TODO: YOUR SOLUTION HERE
correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path34} on the Test Images: %d %%' % (100 * correct / total))

# Get the confusion matrix for the test dataset
# TODO: YOUR SOLUTION HERE
#classes, test_loader, net, device, view_cm=False
cm = utils.get_confusion_matrix(classes, test_loader, model, device)


# See the precision, recall and accuracy per class for the test dataset
# TODO: YOUR SOLUTION HERE
utils.check_precision_recall_accuracy(cm, classes)

# Check the confusion matrix heatmap to visually see the evaluation on the test set
# TODO: YOUR SOLUTION HERE
utils.visualize_confusion_matrix(cm, classes, correct, total)
# Out:
# Accuracy of /kaggle/working/covid-19-RestNet34Adjusted-from-scratch.pt on the Test Images: 75 %
# COVID19 - recall :  0.95683455  precision :  0.88666666  accuracy :  0.9488889
# NORMAL - recall :  0.696  precision :  0.58  accuracy :  0.77555555
# PNEUMONIA - recall :  0.6451613  precision :  0.8  accuracy :  0.7866667
# 0.7555555555555555

# %%
model = torchvision.models.resnet50()

# %%
#print(model)

# %%
# Replacing the last layer(s) of ResNet50 to match our number of classes
# TODO: YOUR SOLUTION HERE
model.fc = nn.Linear(2048, num_classes)
model.to(device)


# Let's define the checkpoint name where the specific model checkpoint will be saved
model_name = "RestNet50Adjusted"
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path50 = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path50)

# Clearing the GPU cache
torch.cuda.empty_cache()


print("Starting training from scratch with network: ", model_name)

epochs = 50
lr = 1e-3

# TODO: YOUR SOLUTION HERE
# Optimizer and loss configurations
criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.Adam(model.parameters(), lr=lr)  # optimizer
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)  # learning rate scheduler



# Initializing the early stopping of the training
early_stopping = utils.EarlyStopping(checkpoint_path50)


# HINT: open the 'ex3_utils.py' file to understand the arguments of 'run_training'
acc, val_acc, loss, val_loss = utils.run_training(train_loader, val_loader, model, epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)
# Out:
# The model checkpoint will be saved here:  /kaggle/working/covid-19-RestNet50Adjusted-from-scratch.pt
# Starting training from scratch with network:  RestNet50Adjusted
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# 450/450: [============================>...] - ETA 0.8s
# Epoch: 1
# Training Loss: 2.909 , Training Accuracy:0.253 => Validation Loss: 1.135, Validation Accuracy: 0.327
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 2
# Training Loss: 1051.690 , Training Accuracy:0.338 => Validation Loss: 2.395, Validation Accuracy: 0.333
# EarlyStopping Counter: 1 out of 5
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 3
# Training Loss: 2.461 , Training Accuracy:0.242 => Validation Loss: 1.506, Validation Accuracy: 0.333
# EarlyStopping Counter: 2 out of 5
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 4
# Training Loss: 1.964 , Training Accuracy:0.047 => Validation Loss: 1.163, Validation Accuracy: 0.333
# EarlyStopping Counter: 3 out of 5
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 5
# Training Loss: 1.491 , Training Accuracy:0.333 => Validation Loss: 1.056, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 6
# Training Loss: 1.193 , Training Accuracy:0.322 => Validation Loss: 1.061, Validation Accuracy: 0.333
# EarlyStopping Counter: 1 out of 5
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 7
# Training Loss: 1.142 , Training Accuracy:0.333 => Validation Loss: 1.060, Validation Accuracy: 0.333
# EarlyStopping Counter: 2 out of 5
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 8
# Training Loss: 1.127 , Training Accuracy:0.333 => Validation Loss: 1.055, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 9
# Training Loss: 1.117 , Training Accuracy:0.333 => Validation Loss: 1.050, Validation Accuracy: 0.333
# 128/450: [====>...........................] - ETA 5.2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 35
#      31 early_stopping = utils.EarlyStopping(checkpoint_path50)
#      34 # HINT: open the 'ex3_utils.py' file to understand the arguments of 'run_training'
# ---> 35 acc, val_acc, loss, val_loss = utils.run_training(train_loader, val_loader, model, epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)
#
# File /kaggle/working/ex3_utils.py:65, in run_training(train_loader, val_loader, net, num_epochs, criterion, optimizer, scheduler, early_stopping, device)
#      63 # computing accuracy
#      64 _, predicted = torch.max(outputs, 1)
# ---> 65 b_len, corr = get_accuracy(predicted, labels)
#      66 num_samples_total += b_len
#      67 correct_total += corr
#
# File /kaggle/working/ex3_utils.py:111, in get_accuracy(predicted, labels)
#     109 batch_len, correct = 0, 0
#     110 batch_len = labels.size(0)
# --> 111 correct = (predicted == labels).sum().item()
#     112 return batch_len, correct
#
# KeyboardInterrupt:

# %%
# Training and validation accuracy plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(acc, val_acc, 'Accuracy')


# Training and validation loss plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(loss, val_loss, 'Loss')

# %%
# Loading the best model for inference (NOTE: you should load the checkpoints to the expected model architecture, else you might get some mismatch errors)
# TODO: YOUR SOLUTION HERE
#load the trained weights
model.load_state_dict(torch.load(checkpoint_path50))


# Provide the testing dataset wrapped in a dataloader to check for inference
# TODO: YOUR SOLUTION HERE
correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path50} on the Test Images: %d %%' % (100 * correct / total))

# Get the confusion matrix for the test dataset
# TODO: YOUR SOLUTION HERE
cm = utils.get_confusion_matrix(classes, test_loader, model, device)


# See the precision, recall and accuracy per class for the test dataset
# TODO: YOUR SOLUTION HERE
utils.check_precision_recall_accuracy(cm, classes)

# Check the confusion matrix heatmap to visually see the evaluation on the test set
# TODO: YOUR SOLUTION HERE
utils.visualize_confusion_matrix(cm, classes, correct, total)

# %% [markdown]
# **Questions**:
#
# 1. How does the performance of the three architectures compare to each other? Are there any specific patterns you can see in the confusion matrices?
# 2. Is there a correlation between the dataset size and depth of the network?
# 3. Given these observations, which model would you prefer for training on a small dataset from scratch?

# %% [markdown]
# **Answers**
# 1. It depends on the hpyerparameters. For specific learning rate we see a decrease in accuracy with larger networks. The network commonly confuses normal lunges and lunges with pneumonia.
# 2. With a bigger data set you are able to train a larger and/or deeper neural network. Large networks tend to overfit on small datasets.
# 3. One should prefer a small model, because large models could overfit a small data set.

# %% [markdown]
# #### Now let's try with Data Augmentation
#
# A common strategy when dealing with small datasets is to add data augmentations.
#
# Let's try a few augmentations from [torchvision.transforms](https://pytorch.org/vision/main/transforms.html) that do not significantly distort the data (stay on the data manifold) and train a ResNet50. Here, we want to see if augmentations allow us to train deeper CNNs.
# Common augmentations for data augmentation are:
# - flipping the inputs along the axes.
# - changing the brightness, contrast and saturation of the inputs.
# - adding small noise to the input.
#
# You can try different combinations of augmentations here. You can add augmentations by updating the `transform` passed to the train dataset. You can again use `Compose` to chain augmentations.
#
# Note; you should only introduce augmentation for the training and validation datasets, **not** for the test dataset. Otherwise the evaluation between models is not consistent anymore.

# %%
# TODO: YOUR SOLUTIONS HERE
# Get the usual transforms to have the inputs from dataloaders as expected
def get_transforms_augmented(height, width, mean, std):
    # TODO: YOUR CODE HERE
    transform = transforms.Compose([transforms.ToImageTensor(), transforms.ConvertImageDtype(), transforms.Normalize(mean, std), transforms.ColorJitter(), transforms.Resize((height, width))])
    return transform


# HINT:
#    - Training a ResNet50 (incorporating data augmentation strategies)
#    = (the training workflows are the same as above)

# %% [markdown]
# We need to apply the new transforms to the dataset and then use our dataloader. Let's reuse our scripts from above, now with the added data augmentation strategies.

# %%
# TODO: YOUR SOLUTION HERE
# Datasets
train_dataset_augmented = torchvision.datasets.ImageFolder(train_dir, transform=get_transforms_augmented(height, width, train_dataset_mean, train_dataset_std))
val_dataset_augmented = torchvision.datasets.ImageFolder(val_dir, transform=get_transforms_augmented(height, width, train_dataset_mean, train_dataset_std))

# TODO: YOUR SOLUTION HERE
# Dataloaders 
train_loader = torch.utils.data.DataLoader(torch.utils.data.ConcatDataset([train_dataset, train_dataset_augmented]), batch_size=batch_size)
val_dataset = torch.utils.data.DataLoader(torch.utils.data.ConcatDataset([val_dataset, val_dataset_augmented]), batch_size=batch_size)

# %% [markdown]
# Now, we are ready to train the ResNet50 with data augmentations. Let's train for longer (30 epochs) here, with the same hyperparameters as before, and evaluate the model on the test set.

# %%
model = torchvision.models.resnet50()

# %%
# Replacing the last layer(s) of ResNet50 to match our number of classes
# TODO: YOUR SOLUTION HERE
model.fc = nn.Linear(2048, num_classes)
model.to(device)


# Let's define the checkpoint name where the specific model checkpoint will be saved
model_name = "RestNet50Adjusted"
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path50 = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path50)

# Clearing the GPU cache
torch.cuda.empty_cache()


print("Starting training from scratch with network: ", model_name)

epochs = 30
lr = 1e-3

# TODO: YOUR SOLUTION HERE
# Optimizer and loss configurations
criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.Adam(model.parameters(), lr=lr)  # optimizer
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)  # learning rate scheduler



# Initializing the early stopping of the training
early_stopping = utils.EarlyStopping(checkpoint_path50)


# HINT: open the 'ex3_utils.py' file to understand the arguments of 'run_training'
acc, val_acc, loss, val_loss = utils.run_training(train_loader, val_loader, model, epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)

# %%
# Training and validation accuracy plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(acc, val_acc, 'Accuracy')


# Training and validation loss plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(loss, val_loss, 'Loss')

# %%
# Loading the best model for inference (NOTE: you should load the checkpoints to the expected model architecture, else you might get some mismatch errors)
# TODO: YOUR SOLUTION HERE
#load the trained weights
model.load_state_dict(torch.load(checkpoint_path50))


# Provide the testing dataset wrapped in a dataloader to check for inference
# TODO: YOUR SOLUTION HERE
correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path50} on the Test Images: %d %%' % (100 * correct / total))

# Get the confusion matrix for the test dataset
# TODO: YOUR SOLUTION HERE
#classes, test_loader, net, device, view_cm=False
cm = utils.get_confusion_matrix(classes, test_loader, model, device)


# See the precision, recall and accuracy per class for the test dataset
# TODO: YOUR SOLUTION HERE
utils.check_precision_recall_accuracy(cm, classes)

# Check the confusion matrix heatmap to visually see the evaluation on the test set
# TODO: YOUR SOLUTION HERE
utils.visualize_confusion_matrix(cm, classes, correct, total)

# %% [markdown]
# **Questions**:
#
# 1. Does the effect of data augmentation match your expectation?
# 2. Are there other kinds of data augmentation that would make sense for this dataset? Think about augmentations that "leave the data manifold".

# %% [markdown]
# ## ImageNet
#
# The [ImageNet project](https://www.image-net.org/) provides a large-scale dataset with natural images. There exist different version of this dataset, the largest using 14 million annotated images for image classification with over 20,000 categories.
#
# This dataset has been used by the ImageNet Scale Visual Recognition Challenge ([ILSVRC](https://image-net.org/challenges/LSVRC/#:~:text=The%20ImageNet%20Large%20Scale%20Visual,image%20classification%20at%20large%20scale.)) to benchmark classification algorithms competing to improve classification. The version fo the dataset used for this classification contains a million training images with 1,000 categeories (and corresponds to the version fo the dataset we discussed in the lecture).
#
# `torchvision.models` has a pool of neural networks, for which pretrained ImageNet weights are also available. To make use of pretrained models, we need to preprocess the images based on the mean and standard deviation of ImageNet (this step is critical!). The statistics for ImageNet are provided [here](https://pytorch.org/vision/main/models/generated/torchvision.models.resnet50.html#:~:text=1.0%5D%20and%20then-,normalized%20using%20mean%3D%5B0.485%2C%200.456%2C%200.406%5D%20and%20std%3D%5B0.229%2C%200.224%2C%200.225%5D.,-Next)
#
# ### ImageNet transfer learning for ResNet50
#
# We will now check if transfer learning from ImageNet leads to improvements for our dataset. Here, we will focus on the ResNet50 as we have seen before that without transfer learning its performance is worse compared to smaller architectures for our dataset.
#
# There are two different approaches for how we can fine-tune a CNN initialized with pretrained weights:
# 1. Update the weights for all layers of the network. For this approach we initialize with pretrained weights but otherwise train the network as before. See this code snippet:
#
#     ```python
#     import torchvision
#     import torch.nn as nn
#
#     model = torchvision.models.resnet50(weights=torchvision.models.ResNet50_Weights.DEFAULT)
#
#     # Let's replace the "fully connected" layer to match our expected output classes
#     model.fc = nn.Linear(<INPUT_FEATURES>, <OUTPUT_CLASSES>)
#     model.to(device)
#
#     # Train the network as usual
#     ```
#
# 2. Only update the weights of the last layer (classification layer). In this case we would "freeze" the pretrained network and use it as a fixed feature extractor. This is achieved by disabling parameter updates for all but the last layer of the network.
#
# We will start with the first approach (fine-tuning the full network).

# %%
# TODO: YOUR SOLUTIONS HERE

# HINT:
#    - Training a ResNet50 (updating all the layers, transfer learning using ImageNet weights)
#    = (the training workflows are the same as above)

model = torchvision.models.resnet50(weights=torchvision.models.ResNet50_Weights.DEFAULT)

# Let's replace the "fully connected" layer to match our expected output classes
model.fc = nn.Linear(2048, num_classes)
#model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 51.9MB/s]

# %%
# TODO: YOUR SOLUTIONS HERE
#adjust mean and std
train_dataset_pre_mean = [0.485, 0.456, 0.406]
train_dataset_pre_std = [0.229, 0.224, 0.225]


# Batch size
batch_size = 64  # TODO: YOUR CHOICE HERE

# Datasets
# TODO: YOUR SOLUTION HERE
train_dataset_pretrained = torchvision.datasets.ImageFolder(train_dir, transform=get_transforms(height, width, train_dataset_pre_mean, train_dataset_pre_std))
val_dataset_pretrained = torchvision.datasets.ImageFolder(val_dir, transform=get_transforms(height, width, train_dataset_pre_mean, train_dataset_pre_std))
test_dataset_pretrained = torchvision.datasets.ImageFolder(test_dir, transform=get_transforms(height, width, train_dataset_pre_mean, train_dataset_pre_std))

# Dataloaders
# TODO: YOUR SOLUTION HERE
train_loader_pretrained = torch.utils.data.DataLoader(train_dataset_pretrained, batch_size=batch_size)
val_loader_pretrained = torch.utils.data.DataLoader(val_dataset_pretrained, batch_size=batch_size)
test_loader_pretrained = torch.utils.data.DataLoader(test_dataset_pretrained, batch_size=batch_size)

# %%
# Let's define the checkpoint name where the specific model checkpoint will be saved
model_name = "RestNet50AdjustedPretrained"
model.to(device)
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path50pre = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path50pre)

# Clearing the GPU cache
torch.cuda.empty_cache()


print("Starting training from scratch with network: ", model_name)

epochs = 30
lr = 1e-5

# TODO: YOUR SOLUTION HERE
# Optimizer and loss configurations
criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.Adam(model.parameters(), lr=lr)  # optimizer
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)  # learning rate scheduler



# Initializing the early stopping of the training
early_stopping = utils.EarlyStopping(checkpoint_path50pre, patience=10)


# HINT: open the 'ex3_utils.py' file to understand the arguments of 'run_training'
acc, val_acc, loss, val_loss = utils.run_training(train_loader_pretrained, val_loader_pretrained, model, epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)
# Out:
# The model checkpoint will be saved here:  /kaggle/working/covid-19-RestNet50AdjustedPretrained-from-scratch.pt
# Starting training from scratch with network:  RestNet50AdjustedPretrained
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 1
# Training Loss: 1.119 , Training Accuracy:0.267 => Validation Loss: 1.092, Validation Accuracy: 0.313
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 2
# Training Loss: 1.123 , Training Accuracy:0.184 => Validation Loss: 1.078, Validation Accuracy: 0.560
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 3
# Training Loss: 1.034 , Training Accuracy:0.604 => Validation Loss: 1.026, Validation Accuracy: 0.673
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 4
# Training Loss: 0.959 , Training Accuracy:0.740 => Validation Loss: 0.959, Validation Accuracy: 0.740
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 5
# Training Loss: 0.871 , Training Accuracy:0.787 => Validation Loss: 0.876, Validation Accuracy: 0.767
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 6
# Training Loss: 0.772 , Training Accuracy:0.838 => Validation Loss: 0.779, Validation Accuracy: 0.833
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 7
# Training Loss: 0.661 , Training Accuracy:0.882 => Validation Loss: 0.664, Validation Accuracy: 0.900
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 8
# Training Loss: 0.524 , Training Accuracy:0.924 => Validation Loss: 0.537, Validation Accuracy: 0.920
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 9
# Training Loss: 0.388 , Training Accuracy:0.942 => Validation Loss: 0.414, Validation Accuracy: 0.927
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 10
# Training Loss: 0.266 , Training Accuracy:0.942 => Validation Loss: 0.314, Validation Accuracy: 0.927
# 450/450: [============================>...] - ETA 0.9s
# Epoch: 11
# Training Loss: 0.185 , Training Accuracy:0.951 => Validation Loss: 0.251, Validation Accuracy: 0.927
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 12
# Training Loss: 0.129 , Training Accuracy:0.964 => Validation Loss: 0.214, Validation Accuracy: 0.933
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 13
# Training Loss: 0.091 , Training Accuracy:0.973 => Validation Loss: 0.193, Validation Accuracy: 0.933
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 14
# Training Loss: 0.064 , Training Accuracy:0.984 => Validation Loss: 0.183, Validation Accuracy: 0.940
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 15
# Training Loss: 0.043 , Training Accuracy:0.993 => Validation Loss: 0.175, Validation Accuracy: 0.947
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 16
# Training Loss: 0.030 , Training Accuracy:0.993 => Validation Loss: 0.173, Validation Accuracy: 0.947
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 17
# Training Loss: 0.020 , Training Accuracy:0.998 => Validation Loss: 0.171, Validation Accuracy: 0.947
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 18
# Training Loss: 0.015 , Training Accuracy:0.998 => Validation Loss: 0.174, Validation Accuracy: 0.947
# EarlyStopping Counter: 1 out of 10
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 19
# Training Loss: 0.010 , Training Accuracy:0.998 => Validation Loss: 0.175, Validation Accuracy: 0.947
# EarlyStopping Counter: 2 out of 10
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 20
# Training Loss: 0.008 , Training Accuracy:0.998 => Validation Loss: 0.176, Validation Accuracy: 0.953
# EarlyStopping Counter: 3 out of 10
# Finished Training

# %%
# Training and validation accuracy plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(acc, val_acc, 'Accuracy')


# Training and validation loss plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(loss, val_loss, 'Loss')

# %%
# Loading the best model for inference (NOTE: you should load the checkpoints to the expected model architecture, else you might get some mismatch errors)
# TODO: YOUR SOLUTION HERE
#load the trained weights
model.load_state_dict(torch.load(checkpoint_path50pre))


# Provide the testing dataset wrapped in a dataloader to check for inference
# TODO: YOUR SOLUTION HERE
correct, total = utils.test_evaluation(model, test_loader_pretrained, device)
print(f'Accuracy of {checkpoint_path50pre} on the Test Images: %d %%' % (100 * correct / total))

# Get the confusion matrix for the test dataset
# TODO: YOUR SOLUTION HERE
#classes, test_loader, net, device, view_cm=False
cm = utils.get_confusion_matrix(classes, test_loader_pretrained, model, device)


# See the precision, recall and accuracy per class for the test dataset
# TODO: YOUR SOLUTION HERE
utils.check_precision_recall_accuracy(cm, classes)

# Check the confusion matrix heatmap to visually see the evaluation on the test set
# TODO: YOUR SOLUTION HERE
utils.visualize_confusion_matrix(cm, classes, correct, total)
# Out:
# Accuracy of /kaggle/working/covid-19-RestNet50AdjustedPretrained-from-scratch.pt on the Test Images: 90 %
# COVID19 - recall :  0.9605263  precision :  0.97333336  accuracy :  0.9777778
# NORMAL - recall :  0.8518519  precision :  0.92  accuracy :  0.92
# PNEUMONIA - recall :  0.89705884  precision :  0.81333333  accuracy :  0.9066667
# 0.9022222222222223

# %% [markdown]
# Now let's try the second approach and finetune only the last layer.
#
# By default all parameters of a network will be updated by gradient descent. The gradient updates can be disabled by setting `requires_grad = False`. So in order to finetune only the last layer you need to `requires_grad = False` for all other layers in the network.
#
# You can see how the parameters are disabled for a complete model in the code snippet below. For the next exercise you need to make sure that `requires_grad` stays `True` for the last layer!
#
# ```python
# for param_name, param in model.named_parameters():
#     param.requires_grad = False
# ```

# %%
# TODO: YOUR SOLUTIONS HERE

# HINT:
#    - Training a ResNet50 (updating all the layers, transfer learning using ImageNet weights)
#    = (the training workflows are the same as above)

model = torchvision.models.resnet50(weights=torchvision.models.ResNet50_Weights.DEFAULT)

# Let's replace the "fully connected" layer to match our expected output classes
model.fc = nn.Linear(2048, num_classes)
#model.to(device)

# %%
for param_name, param in model.named_parameters():
    if param_name in ['fc.weight', 'fc.bias']:
        param.requires_grad = True
    else:
        param.requires_grad = False

# %%
# Let's define the checkpoint name where the specific model checkpoint will be saved
model_name = "RestNet50AdjustedPretrainedLastLayer"
model.to(device)
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path50prell = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path50prell)

# Clearing the GPU cache
torch.cuda.empty_cache()


print("Starting training from scratch with network: ", model_name)

epochs = 30
lr = 1e-1

# TODO: YOUR SOLUTION HERE
# Optimizer and loss configurations
criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.Adam(model.parameters(), lr=lr)  # optimizer
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)  # learning rate scheduler



# Initializing the early stopping of the training
early_stopping = utils.EarlyStopping(checkpoint_path50prell, patience=10)


# HINT: open the 'ex3_utils.py' file to understand the arguments of 'run_training'
acc, val_acc, loss, val_loss = utils.run_training(train_loader_pretrained, val_loader_pretrained, model, epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)
# Out:
# The model checkpoint will be saved here:  /kaggle/working/covid-19-RestNet50AdjustedPretrainedLastLayer-from-scratch.pt
# Starting training from scratch with network:  RestNet50AdjustedPretrainedLastLayer
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 1
# Training Loss: 49.343 , Training Accuracy:0.256 => Validation Loss: 17.992, Validation Accuracy: 0.333
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 2
# Training Loss: 10.816 , Training Accuracy:0.260 => Validation Loss: 6.793, Validation Accuracy: 0.540
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 3
# Training Loss: 8.492 , Training Accuracy:0.404 => Validation Loss: 3.284, Validation Accuracy: 0.713
# 450/450: [============================>...] - ETA 0.6s
# Epoch: 4
# Training Loss: 2.523 , Training Accuracy:0.656 => Validation Loss: 1.097, Validation Accuracy: 0.807
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 5
# Training Loss: 1.503 , Training Accuracy:0.804 => Validation Loss: 1.186, Validation Accuracy: 0.873
# EarlyStopping Counter: 1 out of 10
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 6
# Training Loss: 1.208 , Training Accuracy:0.842 => Validation Loss: 0.742, Validation Accuracy: 0.913
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 7
# Training Loss: 0.426 , Training Accuracy:0.909 => Validation Loss: 0.466, Validation Accuracy: 0.887
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 8
# Training Loss: 0.353 , Training Accuracy:0.927 => Validation Loss: 0.541, Validation Accuracy: 0.900
# EarlyStopping Counter: 1 out of 10
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 9
# Training Loss: 0.232 , Training Accuracy:0.942 => Validation Loss: 0.402, Validation Accuracy: 0.920
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 10
# Training Loss: 0.155 , Training Accuracy:0.971 => Validation Loss: 0.314, Validation Accuracy: 0.933
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 11
# Training Loss: 0.120 , Training Accuracy:0.978 => Validation Loss: 0.342, Validation Accuracy: 0.933
# EarlyStopping Counter: 1 out of 10
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 12
# Training Loss: 0.093 , Training Accuracy:0.980 => Validation Loss: 0.320, Validation Accuracy: 0.940
# EarlyStopping Counter: 2 out of 10
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 13
# Training Loss: 0.071 , Training Accuracy:0.982 => Validation Loss: 0.325, Validation Accuracy: 0.940
# EarlyStopping Counter: 3 out of 10
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 14
# Training Loss: 0.051 , Training Accuracy:0.989 => Validation Loss: 0.340, Validation Accuracy: 0.940
# EarlyStopping Counter: 4 out of 10
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 15
# Training Loss: 0.038 , Training Accuracy:0.993 => Validation Loss: 0.332, Validation Accuracy: 0.940
# EarlyStopping Counter: 5 out of 10
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 16
# Training Loss: 0.030 , Training Accuracy:0.993 => Validation Loss: 0.334, Validation Accuracy: 0.940
# EarlyStopping Counter: 6 out of 10
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 17
# Training Loss: 0.023 , Training Accuracy:0.998 => Validation Loss: 0.347, Validation Accuracy: 0.940
# EarlyStopping Counter: 7 out of 10
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 18
# Training Loss: 0.018 , Training Accuracy:0.998 => Validation Loss: 0.354, Validation Accuracy: 0.940
# EarlyStopping Counter: 8 out of 10
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 19
# Training Loss: 0.014 , Training Accuracy:0.998 => Validation Loss: 0.358, Validation Accuracy: 0.940
# EarlyStopping Counter: 9 out of 10
# 450/450: [============================>...] - ETA 0.5s
# Epoch: 20
# Training Loss: 0.010 , Training Accuracy:0.998 => Validation Loss: 0.359, Validation Accuracy: 0.940
# EarlyStopping Counter: 10 out of 10
# Early Stopping...
# Finished Training

# %%
# Training and validation accuracy plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(acc, val_acc, 'Accuracy')


# Training and validation loss plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(loss, val_loss, 'Loss')

# %%
# Loading the best model for inference (NOTE: you should load the checkpoints to the expected model architecture, else you might get some mismatch errors)
# TODO: YOUR SOLUTION HERE
#load the trained checkpoint_path50prell
model.load_state_dict(torch.load(checkpoint_path50prell))


# Provide the testing dataset wrapped in a dataloader to check for inference
# TODO: YOUR SOLUTION HERE
correct, total = utils.test_evaluation(model, test_loader_pretrained, device)
print(f'Accuracy of {checkpoint_path50prell} on the Test Images: %d %%' % (100 * correct / total))

# Get the confusion matrix for the test dataset
# TODO: YOUR SOLUTION HERE
#classes, test_loader, net, device, view_cm=False
cm = utils.get_confusion_matrix(classes, test_loader, model, device)


# See the precision, recall and accuracy per class for the test dataset
# TODO: YOUR SOLUTION HERE
utils.check_precision_recall_accuracy(cm, classes)

# Check the confusion matrix heatmap to visually see the evaluation on the test set
# TODO: YOUR SOLUTION HERE
utils.visualize_confusion_matrix(cm, classes, correct, total)
# Out:
# Accuracy of /kaggle/working/covid-19-RestNet50AdjustedPretrainedLastLayer-from-scratch.pt on the Test Images: 89 %
# COVID19 - recall :  0.9785714  precision :  0.91333336  accuracy :  0.96444446
# NORMAL - recall :  0.95683455  precision :  0.88666666  accuracy :  0.9488889
# PNEUMONIA - recall :  0.84210527  precision :  0.96  accuracy :  0.9266667
# 0.8933333333333333

# %% [markdown]
# **Questions**:
#
# 1. Elaborate on the reason to use pretrained ImageNet weights for transfer learning (instead of training from scratch).
# 2. Which transfer learning approach performs better for finetuning on our dataset? Comment on the possible reasons!
# 3. Explain the best use-cases for ImageNet pretrained weights for the two different approaches (i.e. when it is a good idea to train from scratch OR for finetuning all layers OR for finetuning last layers).

# %% [markdown]
# **Answers**
# 1. It's better to transfer pretrained weights, because on such a small data set it is nearly impossible to do a senseful training. Through pretrained weights small specific adjustments can be trained leading to overall good results despit the small data set.
# 2. The training of all parameters is slightly better in our case. This makes sense, because the pretrained weights were optimized for a different case. Therefore optimization of all layers makes sense.
# 3. The training of only the last layer is faster and still has a good accuracy.

# %% [markdown]
# **Comment:** When finetuning a model it may also be beneficial to use a different learning rate and change other hyperparameters compared to training from scratch. To keep the exercise simple we do not further explore these options here. If you're interested to investigate these effects you can explore different hyperparameters at the end of the exercise.

# %% [markdown]
# ## RadImageNet
#
# A disadvantage of using ImageNet pretraining for medical images is that the pretraining data is very different to medical images. There are several efforts to build pretraining datasets for the medical image domain, for example [RadImageNet](https://www.radimagenet.com/).
# It contains a pretraining dataset made up of radiology images of a comparable size to ImageNet and provides networks that were pretrained with this dataset.
# - For more details you can check out the [RadImageNet publication](https://doi.org/10.1148/ryai.210315).
#
# Note: if you use on RadImageNet weights you will have to use the statistics below for normalization (corresponding to the image statistics of the RadImageNet dataset):
# ```python
# # Normalization: mean and standard deviation values for the pretrained weights on radimagenet dataset
# radimagenet_mean = (0.223, 0.223, 0.223)
# radimagenet_std = (0.203, 0.203, 0.203)
# ```
#
# We now use pretrained RadImageNet weights for the ResNet50. For this we first need to download those weights and then initialize the architecture correctly. (This is a bit more complex compared to before, so we give you the code for this below.)

# %%
# DO NOT CHANGE
# downloading the radimagenet pretrained model weights
# radimagenet weights - https://drive.google.com/file/d/1RHt2GnuOYlc_gcoTETtBDSW73mFyRAtR/view
! gdown 1RHt2GnuOYlc_gcoTETtBDSW73mFyRAtR

# !unzip -q "/kaggle/working/RadImageNet_pytorch.zip" -d "RadImageNet_Models"

# %%
# DO NOT CHANGE
radimagenet_checkpoint_path = "/kaggle/working/RadImageNet_Models/RadImageNet_pytorch"

resnet50_ckpt = torch.load(os.path.join(radimagenet_checkpoint_path, "ResNet50.pt"))

# %%
# DO NOT CHANGE
# We create the backbone to intialize it with the pretrained weights from radimagenet
class Backbone(nn.Module):
    def __init__(self):
        super().__init__()
        base_model = torchvision.models.resnet50()
        encoder_layers = list(base_model.children())
        self.backbone = nn.Sequential(*encoder_layers[:9])
                        
    def forward(self, x):
        return self.backbone(x)


# We build the classifier to use the features for transfer learning
class Classifier(nn.Module):
    def __init__(self, num_class):
        super().__init__()
        self.drop_out = nn.Dropout()
        self.linear = nn.Linear(2048, num_class)

    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.drop_out(x)
        x = self.linear(x)
        return x

# %% [markdown]
# ## Architecture

# %% [markdown]
# We now combine the backbone (ResNet50 pretrained on RadImageNet) and the classification layer for our dataset.
#
# Train and evaluate this model. You can decide wheter to finetune the whole model or just the last layer.

# %%
# Let's call the backbone (the encoder excluding the last layers)
backbone = Backbone()

# Loading the pretrained weights to the backbone
backbone.load_state_dict(resnet50_ckpt)

# Now let's call the expected fully connected layer
classifier = Classifier(num_class=len(classes))

# Finally, we are ready to build our model 
model = nn.Sequential(backbone, classifier)

# %%
# TODO: YOUR SOLUTIONS HERE

# HINT:
#    - Training a ResNet50 (updating all / last layers, transfer learning using RadImageNet weights)
#    = (the training workflows are the same as above)

# TODO: YOUR SOLUTIONS HERE
#adjust mean and std
radimagenet_mean = (0.223, 0.223, 0.223)
radimagenet_std = (0.203, 0.203, 0.203)


# Batch size
batch_size = 64  # TODO: YOUR CHOICE HERE

# Datasets
# TODO: YOUR SOLUTION HERE
train_dataset_rad_pretrained = torchvision.datasets.ImageFolder(train_dir, transform=get_transforms(height, width, radimagenet_mean, radimagenet_std))
val_dataset_rad_pretrained = torchvision.datasets.ImageFolder(val_dir, transform=get_transforms(height, width, radimagenet_mean, radimagenet_std))
test_dataset_rad_pretrained = torchvision.datasets.ImageFolder(test_dir, transform=get_transforms(height, width, radimagenet_mean, radimagenet_std))

# Dataloaders
# TODO: YOUR SOLUTION HERE
train_loader_rad_pretrained = torch.utils.data.DataLoader(train_dataset_rad_pretrained, batch_size=batch_size)
val_loader_rad_pretrained = torch.utils.data.DataLoader(val_dataset_rad_pretrained, batch_size=batch_size)
test_loader_rad_pretrained = torch.utils.data.DataLoader(test_dataset_rad_pretrained, batch_size=batch_size)

# %%
# Let's define the checkpoint name where the specific model checkpoint will be saved
model_name = "RestNet50AdjustedRadPretrained"
model.to(device)
checkpoint_name = f'covid-19-{model_name}.pt'
checkpoint_path50radpre = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path50radpre)

# Clearing the GPU cache
torch.cuda.empty_cache()

# %%
print("Starting training with network: ", model_name)

epochs = 30
lr = 1e-3

# TODO: YOUR SOLUTION HERE
# Optimizer and loss configurations
criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.Adam(model.parameters(), lr=lr)  # optimizer
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)  # learning rate scheduler



# Initializing the early stopping of the training
early_stopping = utils.EarlyStopping(checkpoint_path50radpre, patience=10)


# HINT: open the 'ex3_utils.py' file to understand the arguments of 'run_training'
acc, val_acc, loss, val_loss = utils.run_training(train_loader_rad_pretrained, val_loader_rad_pretrained, model, epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)

# %%
# Training and validation accuracy plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(acc, val_acc, 'Accuracy')


# Training and validation loss plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(loss, val_loss, 'Loss')

# %%
# Loading the best model for inference (NOTE: you should load the checkpoints to the expected model architecture, else you might get some mismatch errors)
# TODO: YOUR SOLUTION HERE
#load the trained weights
model.load_state_dict(torch.load(checkpoint_path50radpre))


# Provide the testing dataset wrapped in a dataloader to check for inference
# TODO: YOUR SOLUTION HERE
correct, total = utils.test_evaluation(model, test_loader_rad_pretrained, device)
print(f'Accuracy of {checkpoint_path50radpre} on the Test Images: %d %%' % (100 * correct / total))

# Get the confusion matrix for the test dataset
# TODO: YOUR SOLUTION HERE
#classes, test_loader, net, device, view_cm=False
cm = utils.get_confusion_matrix(classes, test_loader, model, device)


# See the precision, recall and accuracy per class for the test dataset
# TODO: YOUR SOLUTION HERE
utils.check_precision_recall_accuracy(cm, classes)

# Check the confusion matrix heatmap to visually see the evaluation on the test set
# TODO: YOUR SOLUTION HERE
utils.visualize_confusion_matrix(cm, classes, correct, total)

# %%
# Let's call the backbone (the encoder excluding the last layers)
backbone = Backbone()

# Loading the pretrained weights to the backbone
backbone.load_state_dict(resnet50_ckpt)

# Now let's call the expected fully connected layer
classifier = Classifier(num_class=len(classes))

# Finally, we are ready to build our model 
model = nn.Sequential(backbone, classifier)

# %%
# Let's define the checkpoint name where the specific model checkpoint will be saved
model_name = "RestNet50AdjustedRadPretrainedLastLayer"
model.to(device)
checkpoint_name = f'covid-19-{model_name}.pt'
checkpoint_path50radprell = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path50radprell)

for param_name, param in model.named_parameters():
    if param_name in ['fc.weight', 'fc.bias']:
        param.requires_grad = True
    #else:
        #param.requires_grad = False

# Clearing the GPU cache
torch.cuda.empty_cache()

# %%
print("Starting training from scratch with network: ", model_name)

epochs = 30
lr = 1e-3

# TODO: YOUR SOLUTION HERE
# Optimizer and loss configurations
criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.Adam(model.parameters(), lr=lr)  # optimizer
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)  # learning rate scheduler



# Initializing the early stopping of the training
early_stopping = utils.EarlyStopping(checkpoint_path50radprell, patience=10)


# HINT: open the 'ex3_utils.py' file to understand the arguments of 'run_training'
acc, val_acc, loss, val_loss = utils.run_training(train_loader_rad_pretrained, val_loader_rad_pretrained, model, epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)

# %%
# Training and validation accuracy plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(acc, val_acc, 'Accuracy')


# Training and validation loss plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(loss, val_loss, 'Loss')

# %%
# Loading the best model for inference (NOTE: you should load the checkpoints to the expected model architecture, else you might get some mismatch errors)
# TODO: YOUR SOLUTION HERE
#load the trained weights
model.load_state_dict(torch.load(checkpoint_path50radprell))


# Provide the testing dataset wrapped in a dataloader to check for inference
# TODO: YOUR SOLUTION HERE
correct, total = utils.test_evaluation(model, test_loader_rad_pretrained, device)
print(f'Accuracy of {checkpoint_path50radprell} on the Test Images: %d %%' % (100 * correct / total))

# Get the confusion matrix for the test dataset
# TODO: YOUR SOLUTION HERE
#classes, test_loader, net, device, view_cm=False
cm = utils.get_confusion_matrix(classes, test_loader, model, device)


# See the precision, recall and accuracy per class for the test dataset
# TODO: YOUR SOLUTION HERE
utils.check_precision_recall_accuracy(cm, classes)

# Check the confusion matrix heatmap to visually see the evaluation on the test set
# TODO: YOUR SOLUTION HERE
utils.visualize_confusion_matrix(cm, classes, correct, total)

# %% [markdown]
# **Questions**:
#
# 1. Comment on your choice of transfer learning approach (either finetuning last layers / all layers in the model) for RadImageNet? Why could the best approach here be different from ImageNet?

# %% [markdown]
# ### Overall Results:
#
# Update the table with your results for all experiments from the exercise:
#
# | Model    | Training                         | Test Accuracy |
# |:-------: |:--------------------------------:|:-------------:|
# | ResNet18 | from scratch                     | 33%               |
# | ResNet34 | from scratch                     | 50%              |
# | ResNet50 | from scratch                     | 68%              |
# | ResNet50 | from scratch (with augmentation) | 90%              |
# | ResNet50 | from ImageNet (all layers)       | 89%              |
# | ResNet50 | from ImageNet (last layers)      | 91%               |
# | ResNet50 | from RadImageNet (all layers)    | 91%         |
# | ResNet50 | from RadImageNet (last layers)   | 88%             |

# %% [markdown]
# **Question**:
# 1. Comment on the trend observed in the results from the table.
# 2. Which is the overall best model? Does this match your expectations? Why/why not?
#
# **Important: please read the end of the exercise sheet and upload the predictions from your best model, also if you choose not to try out to further improve it.**

# %% [markdown]
# **Answers**
# 1. It doesn't make sense to train from scracht. Augmentation makes a significant difference to get more out of small datasets. The feature maps from ImageNet seem quite suitable as well. Overall big networks do a good job on this task.
# 2. ResNet50 with all layers. We thought the RadImageNet would perform better.

# %% [markdown]
# ## (OPTIONAL): Further improve your model.
#
# You can now try to further improve the model by using different architectures or trying some of the advanced training and inference techniques discussed in the lecture. This part of the exercise is optional, and you can try to apply as many approaches for improving your method as you would like. If you don't want to work on the optional part at all please go to the end of the exercise to submit the predictions from your best model.
#
# Here are the aproaches you can try to improve the model:
# 1. Update the training hyperparameter:
#     - You can choose a better initial learning rate, or choose different options for the learning rate scheduler or early stopping.
#     - The most important parameter is probably the learning rate; if you want to improve it then train only for a short time and compare different values. (Remember lecture 2 and the first exercise).
# 2. Try other architectures provided in `torchvision.models`, which implements further CNN architectures (and their respective ImageNet pretrained weights). For example `DenseNet` or `EfficientNet` could yield better results than ResNets.
#     - `torchvision.models` also offers vision transformer architectures (https://arxiv.org/abs/2010.11929). We will cover those later in the lecture, but if you want you can try them here as well. See the snippet at the end of this section for details.
# 3. Try advanced data augmentation strategies, which change the data manifold severly and can boost performance. For example MixUp or CutMix. `torchivsion` already implements them, see [data augmentation with torchvision](https://pytorch.org/vision/stable/transforms.html) for details.
# 4. Try test-time data augmentation. We have covered this idea in the lecture. To use it you don't need to change the training at all, but just update the model prediction during testing. Fot this you can either update the functionality in `ex3_utils.py` or implement a wrapper function or class around the model that implements the test-time data augmentation logic.
# 5. Try model ensembling: combine the predictions of different models on the test set or use an implicit averaging approach like polyak averaging. For this approaches you may need to update the training and/or prediction functions from `ex3_utils.py`.
#
# Here's a snippet that shows how to use vision transformers from torchvision:
#
# ```python
# # replacing the respective layers of the "transformer-based networks" to match our number of classes
# net = torchvision.models.vit_b_16(pretrained=True)
# net.heads.head = nn.Linear(768, num_classes)
# net.to(device)
# ```

# %% [markdown]
# **Hint**: if you want to systematically improve your model you should proceed as follows:
# - Decide on the base architecture and how to initialize it.
#     - Either choose the best model you according to the exercise so far or try if advanced architectures from `torchvision` bring an improvement and continue with one of them.
# - Optimize the training hyperparameters (learning rate, scheduling, early stopping).
# - Investigate advanced techniques:
#   - Training with more or advanced data augmentation.
#   - Test-time data augmentation
#   - Model ensembling
#
# You can divide some of these tasks up among your group and train the best model by combining the best settings you have found for the individual steps.

# %%
# Get the usual transforms to have the inputs from dataloaders as expected
def get_transforms_heavily_augmented(height, width, mean, std, p):
    # TODO: YOUR CODE HERE
    base_transform = transforms.Compose([transforms.ToImageTensor(), transforms.ConvertImageDtype(), transforms.Normalize(mean, std), transforms.Resize((height, width))])
    random_transform = transforms.RandomApply([transforms.ColorJitter(), transforms.GaussianBlur(kernel_size=5), transforms.ElasticTransform(alpha=20.0,sigma=10.0), transforms.Compose([transforms.Pad(padding=10,padding_mode='constant'), transforms.Resize((height, width))]), transforms.RandomRotation((0,10))], p=p)
    transform = transforms.Compose([base_transform, random_transform])
    return transform

# %%
# Datasets
train_dataset_heavily_augmented02 = torchvision.datasets.ImageFolder(train_dir, transform=get_transforms_heavily_augmented(height, width, train_dataset_pre_mean, train_dataset_pre_std,0.2))
train_dataset_heavily_augmented07 = torchvision.datasets.ImageFolder(train_dir, transform=get_transforms_heavily_augmented(height, width, train_dataset_pre_mean, train_dataset_pre_std,0.7))
val_dataset_heavily_augmented = torchvision.datasets.ImageFolder(val_dir, transform=get_transforms(height, width, train_dataset_pre_mean, train_dataset_pre_std))
test_dataset_heavily_augmented = torchvision.datasets.ImageFolder(val_dir, transform=get_transforms(height, width, train_dataset_pre_mean, train_dataset_pre_std))

# TODO: YOUR SOLUTION HERE
# Dataloaders 
train_loader_heavily_augmented02 = torch.utils.data.DataLoader(train_dataset_heavily_augmented02, batch_size=batch_size)
train_loader_heavily_augmented07 = torch.utils.data.DataLoader(train_dataset_heavily_augmented07, batch_size=batch_size)
val_dataset_heavily_augmented = torch.utils.data.DataLoader(val_dataset_heavily_augmented, batch_size=batch_size)
test_dataset_heavily_augmented = torch.utils.data.DataLoader(test_dataset_heavily_augmented, batch_size=batch_size)

# %%
model = torchvision.models.resnet50(weights=torchvision.models.ResNet50_Weights.DEFAULT)

# Let's replace the "fully connected" layer to match our expected output classes
model.fc = nn.Linear(2048, num_classes)

# %%
# Let's define the checkpoint name where the specific model checkpoint will be saved
model_name = "RestNet50Optimal"
model.to(device)
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path50opt = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path50opt)

# Clearing the GPU cache
torch.cuda.empty_cache()

print("Starting training from scratch with network: ", model_name)

epochs = 15
lr = 1e-4

# TODO: YOUR SOLUTION HERE
# Optimizer and loss configurations
criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.Adam(model.parameters(), lr=lr)  # optimizer
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)  # learning rate scheduler



# Initializing the early stopping of the training
early_stopping = utils.EarlyStopping(checkpoint_path50opt, patience=5)


# HINT: open the 'ex3_utils.py' file to understand the arguments of 'run_training'
acc1, val_acc1, loss1, val_loss1 = utils.run_training(train_loader_pretrained, val_loader_pretrained, model, epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)


print("Continuing training with network: ", model_name)

epochs = 15
lr = 1e-4

# TODO: YOUR SOLUTION HERE
# Optimizer and loss configurations
criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.Adam(model.parameters(), lr=lr)  # optimizer
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)  # learning rate scheduler



# Initializing the early stopping of the training
early_stopping = utils.EarlyStopping(checkpoint_path50opt, patience=10)


# HINT: open the 'ex3_utils.py' file to understand the arguments of 'run_training'
acc2, val_acc2, loss2, val_loss2 = utils.run_training(train_loader_heavily_augmented02, val_dataset_heavily_augmented, model, epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)


print("Continuing training with network: ", model_name)

epochs = 30
lr = 1e-5

# TODO: YOUR SOLUTION HERE
# Optimizer and loss configurations
criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.Adam(model.parameters(), lr=lr)  # optimizer
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)  # learning rate scheduler



# Initializing the early stopping of the training
early_stopping = utils.EarlyStopping(checkpoint_path50opt, patience=10)


# HINT: open the 'ex3_utils.py' file to understand the arguments of 'run_training'
acc3, val_acc3, loss3, val_loss3 = utils.run_training(train_loader_heavily_augmented07, val_dataset_heavily_augmented, model, epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)

acc = acc1 + acc2 + acc3
val_acc = val_acc1 + val_acc2 + val_acc3
loss = loss1 + loss2 + loss3
val_loss = val_loss1 + val_loss2 + val_loss3
# Out:
# The model checkpoint will be saved here:  /kaggle/working/covid-19-RestNet50Optimal-from-scratch.pt
# Starting training from scratch with network:  RestNet50Optimal
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 1
# Training Loss: 1.214 , Training Accuracy:0.173 => Validation Loss: 1.132, Validation Accuracy: 0.367
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 2
# Training Loss: 1.093 , Training Accuracy:0.427 => Validation Loss: 1.029, Validation Accuracy: 0.360
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 3
# Training Loss: 1.211 , Training Accuracy:0.013 => Validation Loss: 1.063, Validation Accuracy: 0.367
# EarlyStopping Counter: 1 out of 5
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 4
# Training Loss: 1.141 , Training Accuracy:0.076 => Validation Loss: 1.065, Validation Accuracy: 0.553
# EarlyStopping Counter: 2 out of 5
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 5
# Training Loss: 1.083 , Training Accuracy:0.316 => Validation Loss: 1.046, Validation Accuracy: 0.573
# EarlyStopping Counter: 3 out of 5
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 6
# Training Loss: 1.064 , Training Accuracy:0.418 => Validation Loss: 1.000, Validation Accuracy: 0.533
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 7
# Training Loss: 0.984 , Training Accuracy:0.416 => Validation Loss: 0.928, Validation Accuracy: 0.347
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 8
# Training Loss: 1.084 , Training Accuracy:0.280 => Validation Loss: 0.888, Validation Accuracy: 0.787
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 9
# Training Loss: 0.753 , Training Accuracy:0.767 => Validation Loss: 1.083, Validation Accuracy: 0.333
# EarlyStopping Counter: 1 out of 5
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 10
# Training Loss: 1.205 , Training Accuracy:0.371 => Validation Loss: 0.873, Validation Accuracy: 0.727
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 11
# Training Loss: 0.797 , Training Accuracy:0.724 => Validation Loss: 0.600, Validation Accuracy: 0.747
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 12
# Training Loss: 0.657 , Training Accuracy:0.716 => Validation Loss: 0.537, Validation Accuracy: 0.760
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 13
# Training Loss: 0.524 , Training Accuracy:0.813 => Validation Loss: 0.420, Validation Accuracy: 0.847
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 14
# Training Loss: 0.373 , Training Accuracy:0.876 => Validation Loss: 0.295, Validation Accuracy: 0.907
# 450/450: [============================>...] - ETA 0.7s
# Epoch: 15
# Training Loss: 0.249 , Training Accuracy:0.891 => Validation Loss: 0.256, Validation Accuracy: 0.893
# Finished Training
# Continuing training with network:  RestNet50Optimal
# 450/450: [============================>...] - ETA 1.5ss
# Epoch: 1
# Training Loss: 1.127 , Training Accuracy:0.680 => Validation Loss: 0.730, Validation Accuracy: 0.653
# 450/450: [============================>...] - ETA 2.2ss
# Epoch: 2
# Training Loss: 0.674 , Training Accuracy:0.658 => Validation Loss: 0.471, Validation Accuracy: 0.887
# 450/450: [============================>...] - ETA 1.9ss
# Epoch: 3
# Training Loss: 0.555 , Training Accuracy:0.796 => Validation Loss: 0.399, Validation Accuracy: 0.900
# 450/450: [============================>...] - ETA 1.9ss
# Epoch: 4
# Training Loss: 0.381 , Training Accuracy:0.869 => Validation Loss: 0.391, Validation Accuracy: 0.893
# 450/450: [============================>...] - ETA 2.8ss
# Epoch: 5
# Training Loss: 0.330 , Training Accuracy:0.867 => Validation Loss: 0.331, Validation Accuracy: 0.893
# 450/450: [============================>...] - ETA 1.9ss
# Epoch: 6
# Training Loss: 0.274 , Training Accuracy:0.891 => Validation Loss: 0.287, Validation Accuracy: 0.893
# 450/450: [============================>...] - ETA 2.4ss
# Epoch: 7
# Training Loss: 0.258 , Training Accuracy:0.876 => Validation Loss: 0.258, Validation Accuracy: 0.893
# 450/450: [============================>...] - ETA 2.3ss
# Epoch: 8
# Training Loss: 0.232 , Training Accuracy:0.913 => Validation Loss: 0.240, Validation Accuracy: 0.920
# 450/450: [============================>...] - ETA 2.1ss
# Epoch: 9
# Training Loss: 0.225 , Training Accuracy:0.898 => Validation Loss: 0.254, Validation Accuracy: 0.927
# EarlyStopping Counter: 1 out of 10
# 450/450: [============================>...] - ETA 2.2ss
# Epoch: 10
# Training Loss: 0.145 , Training Accuracy:0.947 => Validation Loss: 0.208, Validation Accuracy: 0.907
# 450/450: [============================>...] - ETA 2.4ss
# Epoch: 11
# Training Loss: 0.143 , Training Accuracy:0.947 => Validation Loss: 0.228, Validation Accuracy: 0.927
# EarlyStopping Counter: 1 out of 10
# 450/450: [============================>...] - ETA 2.3ss
# Epoch: 12
# Training Loss: 0.106 , Training Accuracy:0.949 => Validation Loss: 0.211, Validation Accuracy: 0.927
# EarlyStopping Counter: 2 out of 10
# 450/450: [============================>...] - ETA 1.6ss
# Epoch: 13
# Training Loss: 0.106 , Training Accuracy:0.967 => Validation Loss: 0.242, Validation Accuracy: 0.933
# EarlyStopping Counter: 3 out of 10
# 450/450: [============================>...] - ETA 2.3ss
# Epoch: 14
# Training Loss: 0.064 , Training Accuracy:0.976 => Validation Loss: 0.170, Validation Accuracy: 0.933
# 450/450: [============================>...] - ETA 1.9ss
# Epoch: 15
# Training Loss: 0.071 , Training Accuracy:0.978 => Validation Loss: 0.206, Validation Accuracy: 0.927
# EarlyStopping Counter: 1 out of 10
# Finished Training
# Continuing training with network:  RestNet50Optimal
# 450/450: [============================>...] - ETA 5.8ss
# Epoch: 1
# Training Loss: 0.163 , Training Accuracy:0.931 => Validation Loss: 0.191, Validation Accuracy: 0.940
# 450/450: [============================>...] - ETA 5.6ss
# Epoch: 2
# Training Loss: 0.092 , Training Accuracy:0.956 => Validation Loss: 0.171, Validation Accuracy: 0.933
# 450/450: [============================>...] - ETA 5.1ss
# Epoch: 3
# Training Loss: 0.086 , Training Accuracy:0.953 => Validation Loss: 0.206, Validation Accuracy: 0.920
# EarlyStopping Counter: 1 out of 10
# 450/450: [============================>...] - ETA 5.5ss
# Epoch: 4
# Training Loss: 0.092 , Training Accuracy:0.958 => Validation Loss: 0.171, Validation Accuracy: 0.933
# 450/450: [============================>...] - ETA 6.5ss
# Epoch: 5
# Training Loss: 0.080 , Training Accuracy:0.971 => Validation Loss: 0.158, Validation Accuracy: 0.947
# 450/450: [============================>...] - ETA 6.1ss
# Epoch: 6
# Training Loss: 0.065 , Training Accuracy:0.976 => Validation Loss: 0.154, Validation Accuracy: 0.947
# 450/450: [============================>...] - ETA 5.9ss
# Epoch: 7
# Training Loss: 0.067 , Training Accuracy:0.982 => Validation Loss: 0.159, Validation Accuracy: 0.940
# EarlyStopping Counter: 1 out of 10
# 450/450: [============================>...] - ETA 6.3ss
# Epoch: 8
# Training Loss: 0.052 , Training Accuracy:0.980 => Validation Loss: 0.163, Validation Accuracy: 0.940
# EarlyStopping Counter: 2 out of 10
# 450/450: [============================>...] - ETA 6.3ss
# Epoch: 9
# Training Loss: 0.074 , Training Accuracy:0.964 => Validation Loss: 0.165, Validation Accuracy: 0.947
# EarlyStopping Counter: 3 out of 10
# 450/450: [============================>...] - ETA 5.5ss
# Epoch: 10
# Training Loss: 0.052 , Training Accuracy:0.978 => Validation Loss: 0.167, Validation Accuracy: 0.940
# EarlyStopping Counter: 4 out of 10
# 450/450: [============================>...] - ETA 5.7ss
# Epoch: 11
# Training Loss: 0.048 , Training Accuracy:0.982 => Validation Loss: 0.157, Validation Accuracy: 0.953
# EarlyStopping Counter: 5 out of 10
# 450/450: [============================>...] - ETA 6.8ss
# Epoch: 12
# Training Loss: 0.060 , Training Accuracy:0.978 => Validation Loss: 0.154, Validation Accuracy: 0.960
# 450/450: [============================>...] - ETA 5.3ss
# Epoch: 13
# Training Loss: 0.047 , Training Accuracy:0.989 => Validation Loss: 0.152, Validation Accuracy: 0.960
# 450/450: [============================>...] - ETA 4.8ss
# Epoch: 14
# Training Loss: 0.051 , Training Accuracy:0.984 => Validation Loss: 0.154, Validation Accuracy: 0.953
# EarlyStopping Counter: 1 out of 10
# 450/450: [============================>...] - ETA 5.4ss
# Epoch: 15
# Training Loss: 0.035 , Training Accuracy:0.989 => Validation Loss: 0.142, Validation Accuracy: 0.960
# 450/450: [============================>...] - ETA 5.1ss
# Epoch: 16
# Training Loss: 0.029 , Training Accuracy:0.989 => Validation Loss: 0.140, Validation Accuracy: 0.960
# 450/450: [============================>...] - ETA 5.2ss
# Epoch: 17
# Training Loss: 0.025 , Training Accuracy:0.993 => Validation Loss: 0.144, Validation Accuracy: 0.960
# EarlyStopping Counter: 1 out of 10
# 450/450: [============================>...] - ETA 5.3ss
# Epoch: 18
# Training Loss: 0.034 , Training Accuracy:0.984 => Validation Loss: 0.139, Validation Accuracy: 0.960
# 450/450: [============================>...] - ETA 5.9ss
# Epoch: 19
# Training Loss: 0.038 , Training Accuracy:0.984 => Validation Loss: 0.140, Validation Accuracy: 0.960
# EarlyStopping Counter: 1 out of 10
# 450/450: [============================>...] - ETA 5.3ss
# Epoch: 20
# Training Loss: 0.030 , Training Accuracy:0.989 => Validation Loss: 0.154, Validation Accuracy: 0.947
# EarlyStopping Counter: 2 out of 10
# 450/450: [============================>...] - ETA 6.3ss
# Epoch: 21
# Training Loss: 0.017 , Training Accuracy:0.996 => Validation Loss: 0.149, Validation Accuracy: 0.960
# EarlyStopping Counter: 3 out of 10
# 450/450: [============================>...] - ETA 5.8ss
# Epoch: 22
# Training Loss: 0.024 , Training Accuracy:0.989 => Validation Loss: 0.151, Validation Accuracy: 0.953
# EarlyStopping Counter: 4 out of 10
# 450/450: [============================>...] - ETA 5.3ss
# Epoch: 23
# Training Loss: 0.028 , Training Accuracy:0.989 => Validation Loss: 0.143, Validation Accuracy: 0.960
# EarlyStopping Counter: 5 out of 10
# 450/450: [============================>...] - ETA 5.5ss
# Epoch: 24
# Training Loss: 0.030 , Training Accuracy:0.991 => Validation Loss: 0.141, Validation Accuracy: 0.960
# EarlyStopping Counter: 6 out of 10
# 450/450: [============================>...] - ETA 4.9ss
# Epoch: 25
# Training Loss: 0.025 , Training Accuracy:0.991 => Validation Loss: 0.138, Validation Accuracy: 0.953
# 450/450: [============================>...] - ETA 6.2ss
# Epoch: 26
# Training Loss: 0.019 , Training Accuracy:0.996 => Validation Loss: 0.134, Validation Accuracy: 0.960
# 450/450: [============================>...] - ETA 5.2ss
# Epoch: 27
# Training Loss: 0.017 , Training Accuracy:0.996 => Validation Loss: 0.135, Validation Accuracy: 0.960
# EarlyStopping Counter: 1 out of 10
# 450/450: [============================>...] - ETA 5.5ss
# Epoch: 28
# Training Loss: 0.012 , Training Accuracy:1.000 => Validation Loss: 0.133, Validation Accuracy: 0.967
# 450/450: [============================>...] - ETA 4.9ss
# Epoch: 29
# Training Loss: 0.013 , Training Accuracy:0.998 => Validation Loss: 0.137, Validation Accuracy: 0.967
# EarlyStopping Counter: 1 out of 10
# 450/450: [============================>...] - ETA 5.6ss
# Epoch: 30
# Training Loss: 0.012 , Training Accuracy:0.996 => Validation Loss: 0.147, Validation Accuracy: 0.967
# EarlyStopping Counter: 2 out of 10
# Finished Training

# %%
# Training and validation accuracy plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(acc, val_acc, 'Accuracy')


# Training and validation loss plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(loss, val_loss, 'Loss')

# %%
# Loading the best model for inference (NOTE: you should load the checkpoints to the expected model architecture, else you might get some mismatch errors)
# TODO: YOUR SOLUTION HERE
#load the trained weights
model.load_state_dict(torch.load(checkpoint_path50opt))


# Provide the testing dataset wrapped in a dataloader to check for inference
# TODO: YOUR SOLUTION HERE
correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path50opt} on the Test Images: %d %%' % (100 * correct / total))

# Get the confusion matrix for the test dataset#
# TODO: YOUR SOLUTION HERE
#classes, test_loader, net, device, view_cm=False
cm = utils.get_confusion_matrix(classes, test_loader, model, device)


# See the precision, recall and accuracy per class for the test dataset
# TODO: YOUR SOLUTION HERE
utils.check_precision_recall_accuracy(cm, classes)

# Check the confusion matrix heatmap to visually see the evaluation on the test set
# TODO: YOUR SOLUTION HERE
utils.visualize_confusion_matrix(cm, classes, correct, total)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Accuracy of /kaggle/working/covid-19-RestNet50Optimal-from-scratch.pt on the Test Images: 100 %
# COVID19 - recall :  1.0  precision :  1.0  accuracy :  1.0
# NORMAL - recall :  1.0  precision :  1.0  accuracy :  1.0
# PNEUMONIA - recall :  1.0  precision :  1.0  accuracy :  1.0
# 1.0

# %% [markdown]
# ## Train your best model

# %%
# TODO: IMPLEMENT AND TRAIN THE BEST MODEL HERE

# %% [markdown]
# ## Submission:
#
# - The `unknown` set corresponds to a hold-out test set (with unlabeled images). Such unseen test data is common in machine learning challenges to ensure an objective comparison of different methods and to test how well these solutions would generalize to real data.
# - Submit the predictons from your best model together with your exercise solution.
#     - Upload the solutions to `Stud.IP` -> `Deep Learning for Computer Vision` -> `Files` -> `Submission for Homework 3` -> `Challenge Results`.
#     - Your submission should be called `Tutorial_X_Results_surname1_surname2_surname3.csv`. The expected file format is described below and we provide a function that generates these results for you already.
# - **Please submit the results from your best model (or the model you expect to perform best). If you don't wor on the optional part of the exercise then submit the best result from the models you have trained so far.**
#     - The group with the best submission will get a small prize ;-)
#
# ### Expected Submission Format
#
# Before submitting your results, please make sure that they are in the below mentioned format:
# - `Tutorial_X_Results_<surname1>_<surname2>_<surname3>.csv`
#     - patient_\<ID-1>.jpg | \<CLASS-1>
#     - patient_\<ID-2>.jpg | \<CLASS-2> <br>
#     . <br>
#     . <br>
#     . <br>
#     - patient_\<ID_n>.jpg | \<CLASS-[1-3]>
#
# We have prepared a function that generates these predictions for you (see below).

# %%
# TODO: YOUR SOLUTION HERE
filename = "Tutorial_X.csv"

# Function generating predictions (in a csv file) for the respective images in the hold-out test set (`unknown` folder)
# Note: if you want to use test-time-augmentation or model ensembling you may need to update this function.
# If you don't want to update it you can also create a new class that implements a wrapper around the model(s)
# that implements the augmentation or ensembling logic.
utils.predict_unknown(model, height, width, train_dataset_mean, train_dataset_std, unknown_dir, device, filename)

# Download link is automatically generated for the final results generated
FileLink(filename)
# Out:
#   0%|          | 0/5607 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# 100%|██████████| 5607/5607 [00:57<00:00, 96.67it/s]
# /kaggle/working/Tutorial_X.csv
